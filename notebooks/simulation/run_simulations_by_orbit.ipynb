# %% [markdown]
# # Running simulations
#
# The basic functionality for performing the AWS simulations is implemented by the `aws` package. With this in place, running simulations is a matter of setting up the simulations with the desired parameters and then executing them via IPyParallel.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
import ipyparallel as ipp
import os
import glob
from aws.retrieval import Simulation, Retrieval
from aws.data import Profiles
from aws.sensor import ATMS, AWS
from aws import aws_path

# %% [markdown]
# ## Connecting to IPyParallel
#
# Assuming that the IPyParallel controller, hub and engines are running we create a client, which holds the connection to the controller.

# %%
from aws.retrieval import Retrieval
client = ipp.Client(profile="gold")
view = client.load_balanced_view()

# %% [markdown]
# Since we are already running 4 engines on each of the gold machines, which only have 4 cores, we set the `OMP_NUM_THREADS` environment variable to 1 on all engines to avoid ARTS from launching to many threads.
#
# Note that this notebook is running on your local machine, not on the gold cluster. To execute a cell on the engines we need to use
# the  `%%px` cell magic, which executes the cell on the remote engines instead on the local machine.

# %%
# %%px
# %env OMP_NUM_THREADS=1
# Out:
# [stdout:0] env: OMP_NUM_THREADS=1
# [stdout:1] env: OMP_NUM_THREADS=1
# [stdout:2] env: OMP_NUM_THREADS=1
# [stdout:3] env: OMP_NUM_THREADS=1
# [stdout:4] env: OMP_NUM_THREADS=1
# [stdout:5] env: OMP_NUM_THREADS=1
# [stdout:6] env: OMP_NUM_THREADS=1
# [stdout:7] env: OMP_NUM_THREADS=1
# [stdout:8] env: OMP_NUM_THREADS=1
# [stdout:9] env: OMP_NUM_THREADS=1
# [stdout:10] env: OMP_NUM_THREADS=1
# [stdout:11] env: OMP_NUM_THREADS=1
# [stdout:12] env: OMP_NUM_THREADS=1
# [stdout:13] env: OMP_NUM_THREADS=1
# [stdout:14] env: OMP_NUM_THREADS=1
# [stdout:15] env: OMP_NUM_THREADS=1
# [stdout:16] env: OMP_NUM_THREADS=1
# [stdout:17] env: OMP_NUM_THREADS=1
# [stdout:18] env: OMP_NUM_THREADS=1
# [stdout:19] env: OMP_NUM_THREADS=1
# [stdout:20] env: OMP_NUM_THREADS=1
# [stdout:21] env: OMP_NUM_THREADS=1
# [stdout:22] env: OMP_NUM_THREADS=1
# [stdout:23] env: OMP_NUM_THREADS=1

# %% [markdown]
# ## Setting up the simulation
#
# The next step is to setup the simulation with the desired configuration.

# %% [markdown]
# ## Choosing the sensor
#
# Currently two sensor configurations are available:
#
#   * `ATMS`: Simplified version of the upper channels of the
#      ATMS sensor.
#   * `AWS`: The channel setup to use for the full simulations.

# %%
def simulate_orbit(filename):
    import os
    import numpy as np
    import os
    from aws.retrieval import Simulation, Retrieval
    from aws.data import Profiles
    from aws.sensor import ATMS, AWS
    from aws import aws_path
    
    
    # Simulation settings
    
    sensor = ATMS()
    ice_shape = np.random.choice(["Perpendicular3BulletRosette",
                                  "LargeColumnAggregate",
                                  "LargePlateAggregate"])
    ice_shape_name = ice_shape.rjust(30)
    
    # Input data
    
    data_provider = Profiles(filename)
    retrieval = Retrieval(data_provider, ice_shape)
    data_provider.ice_shape = ice_shape_name
    
    # Setup the simulation
    
    simulation = Simulation(sensor, retrieval, ice_shape)
    
    # Output data
    
    inputs = [("ice_shape", ("name_length",)),] # List of inputs to store in results
    name, _ = os.path.splitext(os.path.basename(filename))
    output_file = os.path.join(os.path.dirname(filename), "..", "ATMS", name + ".nc")
    simulation.initialize_output_file(output_file,
                                     [("cases", -1, 0)], # Name of dimension for different simulations
                                     inputs=inputs)
    # Loop over profiles in file
    simulation.setup()
    
    append = True
    if append:
        n = simulation.output_file.dimensions["cases"]
        simulation.run_ranges(range(n, data_provider.n_profiles))
    else:
        simulation.run_ranges(range(data_provider.n_profiles), "wb")

# %% [markdown]
# ## Execute on view

# %%
files = glob.glob(os.path.expanduser("~/Dendrite/Projects/AWS-325GHz/CasesV1/*.mat"))
print(files)
results = view.map(simulate_orbit, files[:10], block=False)
# Out:
# ['/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_213_01.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_213_02.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_213_03.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_213_04.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_213_05.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_213_06.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_213_07.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_213_08.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_213_09.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_213_10.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_213_11.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_213_12.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_213_13.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_213_14.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_01.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_02.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_03.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_04.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_05.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_06.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_07.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_08.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_09.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_10.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_11.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_12.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_13.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_14.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_214_15.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_01.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_02.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_03.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_04.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_05.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_06.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_07.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_08.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_09.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_10.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_11.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_12.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_13.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_14.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_215_15.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_216_01.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_216_02.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_216_03.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_216_04.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_216_05.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_216_06.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_216_07.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_216_08.mat', '/home/simonpf/Dendrite/Projects/AWS-325GHz/CasesV1/c_of_2015_216_09.mat', '/home/simonpf/Dendrite/ ...

# %%
results[2]
# Out:
# [1:apply]:
# ---------------------------------------------------------------------------Exception                                 Traceback (most recent call last)<string> in <module>
# ~/build/anaconda3/lib/python3.7/site-packages/ipyparallel/client/remotefunction.py in <lambda>(f, *sequences)
#     141
#     142 if sys.version_info[0] >= 3:
# --> 143     _map = lambda f, *sequences: list(map(f, *sequences))
#     144 else:
#     145     _map = map
# <ipython-input-43-0d4ea2e57c62> in simulate_orbit(filename)
# ~/src/artssat/artssat/simulation.py in run_ranges(self, mpi, ipyparallel_client, callback, *args, **kwargs)
#     426                                                 ipyparallel_client=ipyparallel_client)
#     427         else:
# --> 428             self._run_ranges(ranges, **kwargs, callback = callback)
#     429
#     430     def run_checks(self):
# ~/src/artssat/artssat/simulation.py in _run_ranges(self, ranges, callback, *args, **kwargs)
#     396             r = ranges[0]
#     397             for i in r:
# --> 398                 self._run_ranges(ranges[1:], *args, i, **kwargs)
#     399
#     400
# ~/src/artssat/artssat/simulation.py in _run_ranges(self, ranges, callback, *args, **kwargs)
#     386     def _run_ranges(self, ranges, *args, callback = None, **kwargs):
#     387         if len(ranges) == 0:
# --> 388             self.run(*args, **kwargs)
#     389
#     390             if not callback is None:
# ~/src/artssat/artssat/simulation.py in run(self, *args, **kwargs)
#     282         ws = self.workspace
#     283
# --> 284         self.atmosphere.get_data(ws, self.data_provider, *args, **kwargs)
#     285         for s in self.sensors:
#     286             s.get_data(ws, self.data_provider, *args, **kwargs)
# ~/src/artssat/artssat/atmosphere/atmosphere.py in get_data(self, ws, provider, *args, **kwargs)
#     455
#     456         self.cloud_box.get_data(ws, provider, *args, **kwargs)
# --> 457         self.surface.get_data(ws, provider, *args, **kwargs)
#     458
#     459     #
# ~/src/artssat/artssat/atmosphere/surface/surface.py in get_data(self, ws, data_provider, *args, **kwargs)
#     302         self.get_data_arts_properties(ws, data_provider, *args, **kwargs)
#     303
# --> 304         if self.surface_type <= 0.0:
#     305             ws.Copy(ws.surface_rtprop_agenda, self.surface_model_1.surface_agenda)
#     306         else:
# ~/build/arts_release/python/pyarts/workspace/workspace.py in __call__(self, *args, **kwargs)
#     264         self.__doc__  = m.__doc__
#     265
# --> 266     @property
#     267     def ws(self):
#     268         return self._ws()
# ~/build/arts_release/python/pyarts/workspace/methods.py in call(*args, **kwargs)
#     456         if (e_ptr):
#     457             raise Exception("Call to ARTS WSM " + self.name + " failed with error: "
# --> 458                            + e_ptr.decode("utf8").format())
#     459
#     460         # Remove temporaries from workspace (in reverse order).
# Exception: Call to ARTS WSM Copy failed with error: The agenda surface_rtprop_agenda must generate the output WSV surface_skin_t,
# but it does not. It only generates:
#
# [0:apply]:
# ---------------------------------------------------------------------------Exception                                 Traceback (most recent call last)<string> in <module>
# ~/build/anaconda3/lib/python3.7/site-packages/ipyparallel/client/remotefunction.py in <lambda>(f, *sequences)
#     141
#     142 if sys.version_info[0] >= 3:
# --> 143     _map = lambda f, *sequences: list(map(f, *sequences))
#     144 else:
#     145     _map = map
# <ipython-input-43-0d4ea2e57c62> in simulate_orbit(filename)
# ~/src/artssat/artssat/simulation.py in run_ranges(self, mpi, ipyparallel_client, callback, *args, **kwargs)
#     426                                                 ipyparallel_client=ipyparallel_client)
#     427         else:
# --> 428             self._run_ranges(ranges, **kwargs, callback = callback)
#     429
#     430     def run_checks(self):
# ~/src/artssat/artssat/simulation.py in _run_ranges(self, ranges, callback, *args, **kwargs)
#     396             r = ranges[0]
#     397             for i in r:
# --> 398                 self._run_ranges(ranges[1:], *args, i, **kwargs)
#     399
#     400
# ~/src/artssat/artssat/simulation.py in _run_ranges(self, ranges, callback, *args, **kwargs)
#     386     def _run_ranges(self, ranges, *args, callback = None, **kwargs):
#     387         if len(ranges) == 0:
# --> 388             self.run(*args, **kwargs)
#     389
#     390             if not callback is None:
# ~/src/artssat/artssat/simulation.py in run(self, *args, **kwargs)
#     282         ws = self.workspace
#     283
# --> 284         self.atmosphere.get_data(ws, self.data_provider, *args, **kwargs)
#     285         for s in self.sensors:
#     286             s.get_data(ws, self.data_provider, *args, **kwargs)
# ~/src/artssat/artssat/atmosphere/atmosphere.py in get_data(self, ws, provider, *args, **kwargs)
#     455
#     456         self.cloud_box.get_data(ws, provider, *args, **kwargs)
# --> 457         self.surface.get_data(ws, provider, *args, **kwargs)
#     458
#     459     #
# ~/src/artssat/artssat/atmosphere/surface/surface.py in get_data(self, ws, data_provider, *args, **kwargs)
#     302         self.get_data_arts_properties(ws, data_provider, *args, **kwargs)
#     303
# --> 304         if self.surface_type <= 0.0:
#     305             ws.Copy(ws.surface_rtprop_agenda, self.surface_model_1.surface_agenda)
#     306         else:
# ~/build/arts_release/python/pyarts/workspace/workspace.py in __call__(self, *args, **kwargs)
#     264         self.__doc__  = m.__doc__
#     265
# --> 266     @property
#     267     def ws(self):
#     268         return self._ws()
# ~/build/arts_release/python/pyarts/workspace/methods.py in call(*args, **kwargs)
#     456         if (e_ptr):
#     457             raise Exception("Call to ARTS WSM " + self.name + " failed with error: "
# --> 458                            + e_ptr.decode("utf8").format())
#     459
#     460         # Remove temporaries from workspace (in reverse order).
# Exception: Call to ARTS WSM Copy failed with error: The agenda surface_rtprop_agenda must generate the output WSV surface_skin_t,
# but it does not. It only generates:
#
# [8:apply]:
# ---------------------------------------------------------------------------Exception                                 Traceback (most recent call last)<string> in <module>
# ~/build/anaconda3/lib/python3.7/site-packages/ipyparallel/client/remotefunction.py in <lambda>(f, *sequences)
#     141
#     142 if sys.version_info[0] >= 3:
# --> 143     _map = lambda f, *sequences: list(map(f, *sequences))
#     144 else:
#     145     _map = map
# <ipython-input-43-0d4ea2e57c62> in simulate_orbit(filename)
# ~/src/artssat/artssat/simulation.py in run_ranges(self, mpi, ipyparallel_client, callback, *args, **kwargs)
#     426                                                 ipyparallel_client=ipyparallel_client)
#     427         else:
# --> 428             self._run_ranges(ranges, **kwargs, callback = callback)
#     429
#     430     def run_checks(self):
# ~/src/artssat/artssat/simulation.py in _run_ranges(self, ranges, callback, *args, **kwargs)
#     396             r = ranges[0]
#     397             for i in r:
# --> 398                 self._run_ranges(ranges[1:], *args, i, **kwargs)
#     399
#     400
# ~/src/artssat/artssat/simulation.py in _run_ranges(self, ranges, callback, *args, **kwargs)
#     386     def _run_ranges(self, ranges, *args, callback = None, **kwargs):
#     387         if len(ranges) == 0:
# --> 388             self.run(*args, **kwargs)
#     389
#     390             if not callback is None:
# ~/src/artssat/artssat/simulation.py in run(self, *args, **kwargs)
#     282         ws = self.workspace
#     283
# --> 284         self.atmosphere.get_data(ws, self.data_provider, *args, **kwargs)
#     285         for s in self.sensors:
#     286             s.get_data(ws, self.data_provider, *args, **kwargs)
# ~/src/artssat/artssat/atmosphere/atmosphere.py in get_data(self, ws, provider, *args, **kwargs)
#     455
#     456         self.cloud_box.get_data(ws, provider, *args, **kwargs)
# --> 457         self.surface.get_data(ws, provider, *args, **kwargs)
#     458
#     459     #
# ~/src/artssat/artssat/atmosphere/surface/surface.py in get_data(self, ws, data_provider, *args, **kwargs)
#     302         self.get_data_arts_properties(ws, data_provider, *args, **kwargs)
#     303
# --> 304         if self.surface_type <= 0.0:
#     305             ws.Copy(ws.surface_rtprop_agenda, self.surface_model_1.surface_agenda)
#     306         else:
# ~/build/arts_release/python/pyarts/workspace/workspace.py in __call__(self, *args, **kwargs)
#     264         self.__doc__  = m.__doc__
#     265
# --> 266     @property
#     267     def ws(self):
#     268         return self._ws()
# ~/build/arts_release/python/pyarts/workspace/methods.py in call(*args, **kwargs)
#     456         if (e_ptr):
#     457             raise Exception("Call to ARTS WSM " + self.name + " failed with error: "
# --> 458                            + e_ptr.decode("utf8").format())
#     459
#     460         # Remove temporaries from workspace (in reverse order).
# Exception: Call to ARTS WSM Copy failed with error: The agenda surface_rtprop_agenda must generate the output WSV surface_skin_t,
# but it does not. It only generates:
#
# [10:apply]:
# ---------------------------------------------------------------------------Exception                                 Traceback (most recent call last)<string> in <module>
# ~/build/anaconda3/lib/python3.7/site-packages/ipyparallel/client/remotefunction.py in <lambda>(f, *sequences)
#     141
#     142 if sys.version_info[0] >= 3:
# --> 143     _map = lambda f, *sequences: list(map(f, *sequences))
#     144 else:
#     145     _map = map
# <ipython-input-43-0d4ea2e57c62> in simulate_orbit(filename)
# ~/src/artssat/artssat/simulation.py in run_ranges(self, mpi, ipyparallel_client, callback, *args, **kwargs)
#     426                                                 ipyparallel_client=ipyparallel_client)
#     427         else:
# --> 428             self._run_ranges(ranges, **kwargs, callback = callback)
#     429
#     430     def run_checks(self):
# ~/src/artssat/artssat/simulation.py in _run_ranges(self, ranges, callback, *args, **kwargs)
#     396             r = ranges[0]
#     397             for i in r:
# --> 398                 self._run_ranges(ranges[1:], *args, i, **kwargs)
#     399
#     400
# ~/src/artssat/artssat/simulation.py in _run_ranges(self, ranges, callback, *args, **kwargs)
#     386     def _run_ranges(self, ranges, *args, callback = None, **kwargs):
#     387         if len(ranges) == 0:
# --> 388             self.run(*args, **kwargs)
#     389
#     390             if not callback is None:
# ~/src/artssat/artssat/simulation.py in run(self, *args, **kwargs)
#     282         ws = self.workspace
#     283
# --> 284         self.atmosphere.get_data(ws, self.data_provider, *args, **kwargs)
#     285         for s in self.sensors:
#     286             s.get_data(ws, self.data_provider, *args, **kwargs)
# ~/src/artssat/artssat/atmosphere/atmosphere.py in get_data(self, ws, provider, *args, **kwargs)
#     455
#     456         self.cloud_box.get_data(ws, provider, *args, **kwargs)
# --> 457         self.surface.get_data(ws, provider, *args, **kwargs)
#     458
#     459     #
# ~/src/artssat/artssat/atmosphere/surface/surface.py in get_data(self, ws, data_provider, *args, **kwargs)
#     302         self.get_data_arts_properties(ws, data_provider, *args, **kwargs)
#     303
# --> 304         if self.surface_type <= 0.0:
#     305             ws.Copy(ws.surface_rtprop_agenda, self.surface_model_1.surface_agenda)
#     306         else:
# ~/build/arts_release/python/pyarts/workspace/workspace.py in __call__(self, *args, **kwargs)
#     264         self.__doc__  = m.__doc__
#     265
# --> 266     @property
#     267     def ws(self):
#     268         return self._ws()
# ~/build/arts_release/python/pyarts/workspace/methods.py in call(*args, **kwargs)
#     456         if (e_ptr):
#     457             raise Exception("Call to ARTS WSM " + self.name + " failed with error: "
# --> 458                            + e_ptr.decode("utf8").format())
#     459
#     460         # Remove temporaries from workspace (in reverse order).
# Exception: Call to ARTS WSM Copy failed with error: The agenda surface_rtprop_agenda must generate the output WSV surface_skin_t,
# but it does not. It only generates:
#
# ... 5 more exceptions ...
